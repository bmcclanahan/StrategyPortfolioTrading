# %%
import pandas as pd

df = pd.read_parquet('ta_data.parquet')

# %%
import plotly.graph_objects as go

fig = go.Figure()

# %%
df = df[['regime_close', 'regime_ma', 'Date']].drop_duplicates()

# %%
fig.add_trace(

    go.Scattergl(x=df.Date, y=df.regime_close)
)

fig.add_trace(

    go.Scattergl(x=df.Date, y=df.regime_ma)
)
fig

# %%
sym_df = df.loc[df.symbol == 'XOM'].sort_values('Date')

# %%
fig.add_trace(

    go.Scattergl(x=sym_df.Date, y=sym_df.EarningsPerShareBasic)
)

fig
