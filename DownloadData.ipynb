# %%
import pandas as pd
import datetime as dt
import requests_cache

history_length = 20
apikey = '5e225d64b14d31.07865608'
symbol_df_path = 'ITOT_holdings.csv'

# %%
from eod_historical_data import get_eod_data
import requests
import os
import datetime as dt
import requests_cache


def get_symbol_data(symbol, history_length, apikey):
    today = dt.datetime.now().strftime('%Y-%m-%d')
    history = (dt.datetime.now() - dt.timedelta(days=365 * history_length)).strftime('%Y-%m-%d')
    df = get_eod_data(symbol, 'US', start=history, end=today, api_key=apikey)
    df.loc[:, 'symbol'] = symbol
    factor = df.Adjusted_close / df.Close
    df.loc[:, 'adj_close'] = df.Adjusted_close
    df.loc[:, 'adj_open'] = df.Open * factor
    df.loc[:, 'adj_high'] = df.High * factor
    df.loc[:, 'adj_low'] = df.Low * factor
    return df


def download_symbols(api_key, history_length, output_dir, symbol_df,
                     indices, failed_indices):
    for index in indices:
        row = symbol_df.iloc[index]
        symbol = row.symbol
        sector = row.sector
        try:            
            print('\r%d: %s' % (index, symbol))
            df = get_symbol_data(symbol, history_length, apikey)
            df.loc[:, 'sector'] = sector
            df.to_parquet('%s/%s.parquet' % (output_dir, symbol))
        except:
            print('failure occured')
            failed_indices.append(index)

            
def download_data(history_length, apikey, symbol_df_path, output_dir='data', limit=1500):
    expire_after = dt.timedelta(days=1)
    session = requests_cache.CachedSession(cache_name='cache', backend='sqlite', expire_after=expire_after)
    symbol_df = pd.read_csv(symbol_df_path).dropna().iloc[:limit]
    failed_indices = []
    download_symbols(apikey, history_length, output_dir, symbol_df,
                     list(range(symbol_df.shape[0])), failed_indices)
    if len(failed_indices) != 0:
        print('retrying on failed symbols')
        failed_indices2 = []
        download_symbols(apikey, history_length, output_dir, symbol_df,
                         failed_indices, failed_indices2)

# %%
download_data(history_length, apikey, symbol_df_path)
# Out:
# 0: AAPL
# /Users/brianmcclanahan/opt/anaconda3/lib/python3.7/site-packages/eod_historical_data/data.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   parse_dates=[0], index_col=0)
# 1: MSFT
# 2: AMZN
# 3: FB
# 4: GOOGL
# 5: GOOG
# 6: BRKB
# 7: TSLA
# 8: JNJ
# 9: JPM
# 10: V
# 11: PG
# 12: NVDA
# 13: UNH
# 14: MA
# 15: HD
# 16: DIS
# 17: VZ
# 18: PYPL
# 19: CMCSA
# 20: ADBE
# 21: CRM
# 22: BAC
# 23: NFLX
# 24: WMT
# 25: PFE
# 26: T
# 27: KO
# 28: MRK
# 29: INTC
# 30: PEP
# 31: ABT
# 32: ABBV
# 33: CSCO
# 34: TMO
# 35: CVX
# 36: COST
# 37: XOM
# 38: NKE
# 39: MCD
# 40: QCOM
# 41: ACN
# 42: AVGO
# 43: MDT
# 44: NEE
# 45: HON
# 46: TXN
# 47: BMY
# 48: UNP
# 49: DHR
# 50: LIN
# 51: AMGN
# 52: UPS
# 53: PM
# 54: C
# 55: WFC
# 56: LLY
# 57: LOW
# 58: SBUX
# 59: BA
# 60: RTX
# 61: ORCL
# 62: IBM
# 63: AMT
# 64: AMD
# 65: MMM
# 66: NOW
# 67: BLK
# 68: CHTR
# 69: CAT
# 70: INTU
# 71: MS
# 72: LMT
# 73: FIS
# 74: GE
# 75: TGT
# 76: CVS
# 77: XTSLA
# failure occured
# 78: ZM
# 79: ISRG
# 80: BKNG
# 81: SPGI
# 82: MDLZ
# 83: DE
# 84: GS
# 85: SQ
# 86: ANTM
# 87: AXP
# 88: CI
# 89: TMUS
# 90: ZTS
# 91: TJX
# 92: SYK
# 93: AMAT
# 94: GILD
# 95: ADP
# 96: MO
# 97: PLD
# 98: SCHW
# 99: CL
# 100: MU
# 101: UBER
# 102: CCI
# 103: CSX
# 104: DUK
# 105: FDX
# 106: CB
# 107: D
# 108: BDX
# 109: LRCX
# 110: TFC
# 111: FISV
# 112: SO
# 113: CME
# 114: EQIX
# 115: NSC
# 116: APD
# 117: ITW
# 118: USB
# 119: ATVI
# 120: SHW
# 121: ADSK
# 122: PNC
# 123: GPN
# 124: ICE
# 125: VRTX
# 126: MMC
# 127: GM
# 128: ECL
# 129: EL
# 130: DG
# 131: REGN
# 132: HUM
# 133: EW
# 134: PGR
# 135: ADI
# 136: ETN
# 137: KMB
# 138: BSX
# 139: AON
# 140: DD
# 141: NOC
# 142: NEM
# 143: EMR
# 144: ILMN
# 145: WM
# 146: COP
# 147: MCO
# 148: NXPI
# 149: ROP
# 150: TWLO
# 151: LULU
# 152: CTSH
# 153: USD
# 154: LHX
# 155: AEP
# 156: DOCU
# 157: SNAP
# 158: DOW
# 159: EXC
# 160: BX
# 161: HCA
# 162: COF
# 163: APH
# 164: WDAY
# 165: KLAC
# 166: BIIB
# 167: ROST
# 168: BAX
# 169: IDXX
# 170: TEL
# 171: MRNA
# 172: SRE
# 173: VEEV
# 174: GIS
# 175: DLR
# 176: TWTR
# 177: CNC
# 178: MTCH
# 179: CMG
# 180: SYY
# 181: TTD
# 182: MET
# 183: F
# 184: XEL
# 185: EA
# 186: PH
# 187: GD
# 188: A
# 189: PPG
# 190: CSGP
# 191: INFO
# 192: STZ
# 193: EBAY
# 194: TRV
# 195: FCX
# 196: MAR
# 197: TT
# 198: JCI
# 199: MCHP
# 200: XLNX
# 201: SNPS
# 202: AIG
# 203: ALGN
# 204: MSCI
# 205: CMI
# 206: PSA
# 207: TROW
# 208: APTV
# 209: ORLY
# 210: BK
# 211: YUM
# 212: ALL
# 213: IQV
# 214: VRSK
# 215: PINS
# 216: SPLK
# 217: CDNS
# 218: TDG
# 219: SBAC
# 220: BLL
# 221: CTAS
# 222: CARR
# 223: ZBH
# 224: MNST
# 225: PRU
# 226: HPQ
# 227: DXCM
# 228: PCAR
# 229: WEC
# 230: SLB
# 231: PEG
# 232: MRVL
# 233: PAYX
# 234: AFL
# 235: RMD
# 236: ES
# 237: ROK
# 238: SWK
# 239: EOG
# 240: MCK
# 241: ROKU
# 242: MSI
# 243: CTVA
# 244: KMI
# 245: HLT
# 246: GLW
# 247: PANW
# 248: ANSS
# 249: LUV
# 250: WBA
# 251: AWK
# 252: PSX
# 253: AME
# 254: ADM
# 255: FAST
# 256: VFC
# 257: OKTA
# 258: OTIS
# 259: ALXN
# 260: MTD
# 261: WLTW
# 262: SPG
# 263: WELL
# 264: MPC
# 265: AZO
# 266: DLTR
# 267: ED
# 268: DAL
# 269: WMB
# 270: CLX
# 271: BBY
# 272: STT
# 273: KR
# 274: DHI
# 275: DTE
# 276: DFS
# 277: LBRDK
# 278: FTV
# 279: EIX
# 280: AVB
# 281: TDOC
# 282: CPRT
# 283: VLO
# 284: MKC
# 285: RNG
# 286: CERN
# 287: CRWD
# 288: AMP
# 289: SWKS
# 290: FLT
# 291: PPL
# 292: KEYS
# 293: LYB
# 294: PTON
# 295: ETR
# 296: FRC
# 297: COUP
# 298: MXIM
# 299: AJG
# 300: HSY
# 301: WY
# 302: LEN
# 303: CHD
# 304: KHC
# 305: KKR
# 306: O
# 307: CBRE
# 308: SGEN
# 309: WST
# 310: VTRS
# 311: RSG
# 312: EQR
# 313: PAYC
# 314: VRSN
# 315: NTRS
# 316: TTWO
# 317: MKTX
# 318: EFX
# 319: VIAC
# 320: AEE
# 321: LH
# 322: IP
# 323: ZBRA
# 324: ODFL
# 325: ETSY
# 326: TSN
# 327: ARE
# 328: VMC
# 329: GWW
# 330: LVS
# 331: SIVB
# 332: PCG
# 333: CDW
# 334: FITB
# 335: EPAM
# 336: KSU
# 337: VTR
# 338: AMCR
# 339: DOV
# 340: CMS
# 341: TER
# 342: KDP
# 343: HOLX
# 344: EXAS
# 345: PXD
# 346: ENPH
# 347: W
# 348: WORK
# 349: CAG
# 350: TYL
# 351: TRU
# 352: XYL
# 353: EXPE
# 354: TFX
# 355: GRMN
# 356: DDOG
# 357: QRVO
# 358: BR
# 359: URI
# 360: DGX
# 361: SYF
# 362: IR
# 363: NUE
# 364: PODD
# 365: FTNT
# 366: AKAM
# 367: HUBS
# 368: MLM
# 369: HIG
# 370: OKE
# 371: STE
# 372: COO
# 373: DELL
# 374: K
# 375: ESS
# 376: PEAK
# 377: KEY
# 378: DKNG
# 379: CE
# 380: TSCO
# 381: VAR
# 382: ULTA
# 383: CTLT
# 384: INVH
# 385: MTB
# 386: INCY
# 387: CAH
# 388: ZEN
# 389: HAL
# 390: SSNC
# 391: DPZ
# 392: ABC
# 393: Z
# 394: KMX
# 395: RF
# 396: CTXS
# 397: ALNY
# 398: TRMB
# 399: BFB
# 400: ANET
# 401: BXP
# 402: CFG
# 403: HZNP
# 404: ALB
# 405: BMRN
# 406: FMC
# 407: EXPD
# 408: FE
# 409: DRI
# 410: PKI
# 411: MAA
# 412: BURL
# 413: TDY
# 414: SEDG
# 415: NDAQ
# 416: GPC
# 417: RCL
# 418: AES
# 419: IEX
# 420: MKL
# 421: DRE
# 422: CZR
# 423: AVLR
# 424: WAT
# 425: POOL
# 426: TIF
# 427: HPE
# 428: EXR
# 429: CVNA
# 430: OXY
# 431: BKI
# 432: GNRC
# 433: MAS
# 434: FICO
# 435: SUI
# 436: EMN
# 437: WDC
# 438: J
# 439: VICI
# 440: MDB
# 441: IT
# 442: HES
# 443: OMC
# 444: NVR
# 445: MPWR
# 446: AVTR
# 447: ACGL
# 448: SJM
# 449: HRL
# 450: LNT
# 451: GDDY
# 452: PFG
# 453: LDOS
# 454: CNP
# 455: STX
# 456: UAL
# 457: LNG
# 458: CDAY
# 459: BKR
# 460: WAB
# 461: MASI
# 462: CCK
# 463: EVRG
# 464: CGNX
# 465: HBAN
# 466: AVY
# 467: CHRW
# 468: CXO
# 469: JKHY
# 470: PKG
# 471: ABMD
# 472: BAH
# 473: WPC
# 474: WHR
# 475: MOH
# 476: FDS
# 477: IFF
# 478: ENTG
# 479: FBHS
# 480: PLUG
# 481: NTAP
# 482: PHM
# 483: ATO
# 484: TECH
# 485: MGM
# 486: HAS
# 487: GGG
# 488: PTC
# 489: NUAN
# 490: MTN
# 491: ON
# 492: RJF
# 493: IAC
# 494: BIO
# 495: WRK
# 496: CRL
# 497: RPM
# 498: ATUS
# 499: CINF
# 500: VMW
# 501: NLY
# 502: JBHT
# 503: CCL
# 504: UDR
# 505: ALLY
# 506: XRAY
# 507: SRPT
# 508: NDSN
# 509: NET
# 510: PENN
# 511: EQH
# 512: ZS
# 513: NLOK
# 514: BRO
# 515: HST
# 516: CABO
# 517: NVCR
# 518: LW
# 519: L
# 520: TXT
# 521: CREE
# 522: WTRG
# 523: FNF
# 524: LUMN
# 525: ALLE
# 526: MRTX
# 527: GWRE
# 528: MPW
# 529: ELAN
# 530: BFAM
# 531: UHS
# 532: RUN
# 533: LKQ
# 534: AAP
# 535: GH
# 536: PWR
# 537: FFIV
# 538: ELS
# 539: CPB
# 540: WYNN
# 541: TTC
# 542: SNA
# 543: FOXA
# 544: OLED
# 545: LII
# 546: GL
# 547: TXG
# 548: CBOE
# 549: BWA
# 550: VST
# 551: CHGG
# 552: HWM
# 553: PNW
# 554: XPO
# 555: CPT
# 556: LYV
# 557: FIVN
# 558: LYFT
# 559: PLAN
# 560: AZPN
# 561: APO
# 562: MSFUT
# failure occured
# 563: DISH
# 564: SNOW
# 565: PNR
# 566: GLIBA
# 567: RE
# 568: LB
# 569: HSIC
# 570: RNR
# 571: ARMK
# 572: NI
# 573: WU
# 574: SCI
# 575: IPG
# 576: LNC
# 577: RGEN
# 578: TREX
# 579: Y
# 580: GLPI
# 581: WSM
# 582: TAP
# 583: BG
# 584: ACM
# 585: WRB
# 586: AGNC
# 587: FWONK
# 588: NBIX
# 589: CF
# 590: FIVE
# 591: HDS
# 592: HUBB
# 593: ROL
# 594: FND
# 595: DNKN
# 596: CSL
# 597: AAXN
# 598: TPR
# 599: OHI
# 600: DVA
# 601: FSLR
# 602: VER
# 603: AIZ
# 604: SAM
# 605: HEIA
# 606: GNTX
# 607: NWL
# 608: ZNGA
# 609: RGA
# 610: ST
# 611: EHC
# 612: MOS
# 613: LAD
# 614: AMED
# 615: IAA
# 616: LEA
# 617: SIRI
# 618: STOR
# 619: ATR
# 620: MHK
# 621: OC
# 622: RARE
# 623: CONE
# 624: DAR
# 625: JAZZ
# 626: UGI
# 627: LBTYK
# 628: NRG
# 629: IPHI
# 630: PCTY
# 631: AMH
# 632: IRM
# 633: WEX
# 634: MIDD
# 635: DISCK
# 636: AAL
# 637: RHI
# 638: JNPR
# 639: PEN
# 640: CHE
# 641: EV
# 642: APPN
# 643: EEFT
# 644: VOYA
# 645: NCLH
# 646: RS
# 647: LSXMK
# 648: AOS
# 649: ALV
# 650: STLD
# 651: WSO
# 652: G
# 653: IONS
# 654: IPGP
# 655: QDEL
# 656: LPLA
# 657: MKSI
# 658: DECK
# 659: SMG
# 660: RGLD
# 661: ESTC
# 662: LECO
# 663: DT
# 664: BERY
# 665: REG
# 666: NVAX
# 667: CMA
# 668: IIVI
# 669: RH
# 670: BYND
# 671: BILL
# 672: SEE
# 673: PRAH
# 674: LAMR
# 675: HII
# 676: FANG
# 677: AFG
# 678: CIEN
# 679: COG
# 680: COLD
# 681: ARW
# 682: JLL
# 683: USFD
# 684: KIM
# 685: SEIC
# 686: DCI
# 687: CASY
# 688: CBSH
# 689: NVTA
# 690: NTRA
# 691: KRC
# 692: FHN
# 693: SNX
# 694: IRTC
# 695: IVZ
# 696: NWSA
# 697: NNN
# 698: OGE
# 699: ZION
# 700: TTEK
# 701: TMX
# 702: CHDN
# 703: HRC
# 704: ITT
# 705: ACAD
# 706: SMAR
# 707: LITE
# 708: BL
# 709: PRGO
# 710: SBNY
# 711: VNO
# 712: LHCG
# 713: ALK
# 714: ARWR
# 715: MANH
# 716: FOLD
# 717: WWD
# 718: GRUB
# 719: AYX
# 720: CACI
# 721: NYT
# 722: FSLY
# 723: DXC
# 724: SRCL
# 725: EWBC
# 726: PVH
# 727: SITE
# 728: HOG
# 729: FRT
# 730: BEN
# 731: AXTA
# 732: EXEL
# 733: NVRO
# 734: DVN
# 735: LFUS
# 736: CLGX
# 737: CUBE
# 738: PLNT
# 739: PB
# 740: OSK
# 741: PFPT
# 742: POST
# 743: HTA
# 744: UTHR
# 745: BPMC
# 746: AGCO
# 747: LEG
# 748: HAE
# 749: BC
# 750: SON
# 751: QTWO
# 752: RP
# 753: REXR
# 754: EGP
# 755: SAIC
# 756: DLB
# 757: XLRN
# 758: NLSN
# 759: VAC
# 760: DBX
# 761: ATH
# 762: CDK
# 763: PBCT
# 764: AIV
# 765: BLD
# 766: ERIE
# 767: BWXT
# 768: PFGC
# 769: HALO
# 770: TCF
# 771: JBL
# 772: PEGA
# 773: TRGP
# 774: MAT
# 775: FR
# 776: MAN
# 777: TOL
# 778: KNX
# 779: HELE
# 780: BJ
# 781: ACC
# 782: TW
# 783: IOVA
# 784: BRKR
# 785: PII
# 786: MDU
# 787: OLLI
# 788: CPRI
# 789: HUN
# 790: THO
# 791: COR
# 792: TNDM
# 793: HQY
# 794: CW
# 795: KSS
# 796: DEI
# 797: CHWY
# 798: LSCC
# 799: DNLI
# 800: WH
# 801: FAF
# 802: WAL
# 803: FFIN
# 804: FLIR
# 805: FRPT
# 806: NTNX
# 807: BRKS
# 808: HEI
# 809: APA
# 810: HBI
# 811: MRO
# 812: TPX
# 813: MSA
# 814: JEF
# 815: SF
# 816: STWD
# 817: HLF
# 818: NATI
# 819: INGR
# 820: SLAB
# 821: NOV
# 822: KNSL
# 823: UNM
# 824: SNV
# 825: LSI
# 826: SSB
# 827: CUZ
# 828: PRI
# 829: INSP
# 830: ORI
# 831: NEO
# 832: EME
# 833: KMPR
# 834: NXST
# 835: LSTR
# 836: TXRH
# 837: FLS
# 838: BRX
# 839: CRUS
# 840: TKR
# 841: RXN
# 842: ESNT
# 843: IDA
# 844: AYI
# 845: NVST
# 846: TPTX
# 847: SKX
# 848: GPS
# 849: HXL
# 850: NYCB
# 851: QRTEA
# 852: RDFN
# 853: VNT
# 854: MMS
# 855: SYNH
# 856: FOX
# 857: YETI
# 858: RBC
# 859: BHVN
# 860: PSTG
# 861: BPOP
# 862: GPK
# 863: ALSN
# 864: OMCL
# 865: CLF
# 866: STAG
# 867: FLO
# 868: ROLL
# 869: CFR
# 870: SAIA
# 871: PNFP
# 872: BLDR
# 873: EVBG
# 874: XRX
# 875: JHG
# 876: CCMP
# 877: MORN
# 878: EXPO
# 879: AAN
# 880: AMG
# 881: DISCA
# 882: LOPE
# 883: TWST
# 884: PE
# 885: FL
# 886: ASGN
# 887: MTG
# 888: VVV
# 889: LAZ
# 890: SMTC
# 891: GMED
# 892: ARES
# 893: ENV
# 894: IBKR
# 895: AEIS
# 896: RAMP
# 897: HR
# 898: SLG
# 899: CROX
# 900: BXMT
# 901: OGS
# 902: DKS
# 903: EQT
# 904: EXP
# 905: WEN
# 906: KOD
# 907: SAIL
# 908: ASH
# 909: SSD
# 910: POWI
# 911: HIW
# 912: NOVT
# 913: THG
# 914: AWI
# 915: WYND
# 916: NEOG
# 917: JCOM
# 918: FTDR
# 919: RETA
# 920: RL
# 921: FATE
# 922: HPP
# 923: CC
# 924: AL
# 925: VRT
# 926: VLY
# 927: RPD
# 928: BFA
# 929: FCNCA
# 930: RYN
# 931: RDN
# 932: PK
# 933: NVT
# 934: PTCT
# 935: EVR
# 936: TRNO
# 937: JBLU
# 938: WSC
# 939: IRDM
# 940: CLH
# 941: CHNG
# 942: MSM
# 943: HRB
# 944: AXS
# 945: BKH
# 946: IART
# 947: DOC
# 948: CFX
# 949: SPCE
# 950: PNM
# 951: INSM
# 952: HE
# 953: AA
# 954: NRZ
# 955: LBRDA
# 956: SAGE
# 957: FCN
# 958: MRCY
# 959: AN
# 960: SLM
# 961: SIGI
# 962: ADPT
# 963: SRC
# 964: NKLA
# 965: ACIW
# 966: HASI
# 967: ACHC
# 968: KBR
# 969: BBIO
# 970: NCR
# 971: WMS
# 972: GTLS
# 973: FTI
# 974: ZG
# 975: POR
# 976: ICUI
# 977: XEC
# 978: CRI
# 979: FEYE
# 980: VRNT
# 981: JBGS
# 982: SABR
# 983: CR
# 984: SPR
# 985: ARNA
# 986: NFG
# 987: HFC
# 988: LPX
# 989: WTFC
# 990: BCPC
# 991: GBCI
# 992: IIPR
# 993: JBT
# 994: CBRL
# 995: SPSC
# 996: X
# 997: THC
# 998: ADC
# 999: BCO
# 1000: OVV
# 1001: ENS
# 1002: SWX
# 1003: OLN
# 1004: MTZ
# 1005: LSXMA
# 1006: DNB
# 1007: PRLB
# 1008: UBSI
# 1009: RLI
# 1010: VRNS
# 1011: PPD
# 1012: LBTYA
# 1013: FGEN
# 1014: EBS
# 1015: MUSA
# 1016: QTS
# 1017: WBS
# 1018: AIMC
# 1019: LANC
# 1020: EYE
# 1021: CDLX
# 1022: VMI
# 1023: WING
# 1024: TRUP
# 1025: FOXF
# 1026: ETRN
# 1027: STL
# 1028: UFPI
# 1029: AVNT
# 1030: MEDP
# 1031: NWE
# 1032: RHP
# 1033: UPWK
# 1034: ALRM
# 1035: ENSG
# 1036: CBU
# 1037: ITRI
# 1038: BHF
# 1039: FNB
# 1040: SR
# 1041: NSP
# 1042: HLI
# 1043: HAIN
# 1044: LCII
# 1045: STAA
# 1046: OZK
# 1047: TNET
# 1048: CACC
# 1049: CIT
# 1050: CG
# 1051: SBRA
# 1052: TMHC
# 1053: M
# 1054: UHAL
# 1055: QLYS
# 1056: CRNC
# 1057: NEWR
# 1058: MTH
# 1059: NJR
# 1060: UNF
# 1061: LPSN
# 1062: GRA
# 1063: CNNE
# 1064: CDNA
# 1065: RPRX
# 1066: WDFC
# 1067: STMP
# 1068: WPX
# 1069: PRSP
# 1070: AVT
# 1071: UNVR
# 1072: SXT
# 1073: DIOD
# 1074: ADS
# 1075: R
# 1076: KEX
# 1077: HHC
# 1078: WTS
# 1079: PACW
# 1080: OMF
# 1081: GO
# 1082: ORA
# 1083: BAND
# 1084: BOH
# 1085: APLE
# 1086: VIAV
# 1087: UAA
# 1088: VC
# 1089: UMPQ
# 1090: TGNA
# 1091: OSTK
# 1092: BYD
# 1093: COHR
# 1094: UMBF
# 1095: EQC
# 1096: CCXI
# 1097: SWAV
# 1098: EPR
# 1099: TGTX
# 1100: AMN
# 1101: NGVT
# 1102: MSGS
# 1103: KWR
# 1104: WRI
# 1105: FHB
# 1106: CWST
# 1107: APPS
# 1108: ESGR
# 1109: NKTR
# 1110: ZI
# 1111: FORM
# 1112: WK
# 1113: HOMB
# 1114: EXLS
# 1115: ALE
# 1116: BMCH
# 1117: ALLK
# 1118: MMSI
# 1119: PACB
# 1120: KBH
# 1121: OFC
# 1122: GATX
# 1123: CHH
# 1124: PPBI
# 1125: FCFS
# 1126: PCRX
# 1127: KMT
# 1128: PCH
# 1129: TRIP
# 1130: ESI
# 1131: SYNA
# 1132: NHI
# 1133: NEU
# 1134: AIT
# 1135: ALKS
# 1136: SCL
# 1137: MATX
# 1138: GKOS
# 1139: UA
# 1140: BLUE
# 1141: BBBY
# 1142: CNO
# 1143: MOGA
# 1144: BOX
# 1145: JWN
# 1146: WLK
# 1147: ARNC
# 1148: HWC
# 1149: HI
# 1150: TRTN
# 1151: HL
# 1152: CHX
# 1153: PSB
# 1154: VCYT
# 1155: CIM
# 1156: CNMD
# 1157: ABM
# 1158: LIVN
# 1159: SPXC
# 1160: DOOR
# 1161: TCO
# 1162: ADNT
# 1163: AJRD
# 1164: MDLA
# 1165: VG
# 1166: AVA
# 1167: ENR
# 1168: AWR
# 1169: TREE
# 1170: ACIA
# 1171: LXP
# 1172: ROG
# 1173: CBT
# 1174: PZZA
# 1175: BXS
# 1176: SHOO
# 1177: MGNI
# 1178: RCM
# 1179: OUT
# 1180: AGR
# 1181: GBT
# 1182: WTM
# 1183: SHAK
# 1184: ESE
# 1185: GT
# 1186: GDOT
# 1187: TWOU
# 1188: REZI
# 1189: KTOS
# 1190: HMSY
# 1191: ASB
# 1192: TDC
# 1193: ITGR
# 1194: HGV
# 1195: DAN
# 1196: ISBC
# 1197: TCBI
# 1198: BLKB
# 1199: NSIT
# 1200: MIC
# 1201: SVMK
# 1202: CVBF
# 1203: MGEE
# 1204: REGI
# 1205: CWT
# 1206: CVET
# 1207: SAFM
# 1208: PEB
# 1209: TPH
# 1210: AUB
# 1211: ACA
# 1212: CVLT
# 1213: MDRX
# 1214: DORM
# 1215: HP
# 1216: MIME
# 1217: WKHS
# 1218: ONB
# 1219: PDCO
# 1220: FUL
# 1221: FHI
# 1222: AAON
# 1223: AEO
# 1224: SEM
# 1225: SLGN
# 1226: YELP
# 1227: MDC
# 1228: JJSF
# 1229: AMBA
# 1230: WWW
# 1231: KAR
# 1232: FLR
# 1233: IBP
# 1234: APG
# 1235: FN
# 1236: AZEK
# 1237: DCPH
# 1238: NUVA
# 1239: NUS
# 1240: PFSI
# 1241: FELE
# 1242: CORT
# 1243: VSH
# 1244: WCC
# 1245: FLOW
# 1246: ONEM
# 1247: AGIO
# 1248: AIN
# 1249: APLS
# 1250: SFM
# 1251: COMM
# 1252: CSOD
# 1253: WOR
# 1254: NSTG
# 1255: CCOI
# 1256: MC
# 1257: SIX
# 1258: KURA
# 1259: SFIX
# 1260: TENB
# 1261: BKU
# 1262: H
# 1263: CMP
# 1264: APAM
# 1265: SPB
# 1266: XNCR
# 1267: SKYW
# 1268: COLM
# 1269: URBN
# 1270: EVTC
# 1271: JACK
# 1272: MSTR
# 1273: PDM
# 1274: WERN
# 1275: CNX
# 1276: MED
# 1277: SHO
# 1278: SNBR
# 1279: SDGR
# 1280: EPRT
# 1281: MTOR
# 1282: SUM
# 1283: RRC
# 1284: APPF
# 1285: PSMT
# 1286: CMC
# 1287: GSHD
# 1288: KFY
# 1289: GPI
# 1290: INT
# 1291: PINC
# 1292: SONO
# 1293: WMG
# 1294: SGMS
# 1295: B
# 1296: CLDR
# 1297: BMI
# 1298: IOSP
# 1299: AQUA
# 1300: EAT
# 1301: MTX
# 1302: WSFS
# 1303: CTB
# 1304: FCEL
# 1305: NGHC
# 1306: AM
# 1307: KW
# 1308: CATY
# 1309: IBTX
# 1310: NTLA
# 1311: STRA
# 1312: NAVI
# 1313: KLIC
# 1314: LGIH
# 1315: THS
# 1316: AVNS
# 1317: MXL
# 1318: ONTO
# 1319: WD
# 1320: IDCC
# 1321: VSAT
# 1322: CLNY
# 1323: CARG
# 1324: ATKR
# 1325: ABG
# 1326: IRBT
# 1327: RLJ
# 1328: CMD
# 1329: MFA
# 1330: PAG
# 1331: INDB
# 1332: MGLN
# 1333: VNE
# 1334: SFNC
# 1335: FULT
# 1336: SJI
# 1337: UCBI
# 1338: VRRM
# 1339: BE
# 1340: VICR
# 1341: BOKF
# 1342: HLNE
# 1343: COTY
# 1344: NOVA
# 1345: COOP
# 1346: TDS
# 1347: LTHM
# 1348: VIRT
# 1349: RKT
# 1350: CWEN
# 1351: ATRC
# 1352: AGO
# 1353: RVMD
# 1354: SAVE
# 1355: NAV
# 1356: MLHR
# 1357: FWRD
# 1358: NWS
# 1359: ALGT
# 1360: EHTH
# 1361: PJT
# 1362: XPER
# 1363: TWNK
# 1364: MANT
# 1365: AXSM
# 1366: CFFN
# 1367: GNW
# 1368: WGO
# 1369: COLB
# 1370: ALTR
# 1371: INO
# 1372: TEX
# 1373: BIG
# 1374: ROCK
# 1375: AEL
# 1376: UNIT
# 1377: SVC
# 1378: SWN
# 1379: KTB
# 1380: FSS
# 1381: SHEN
# 1382: BRC
# 1383: PBH
# 1384: STAY
# 1385: RPAI
# 1386: UFS
# 1387: BDN
# 1388: SILK
# 1389: HUBG
# 1390: PLXS
# 1391: MWA
# 1392: ABCB
# 1393: WAFD
# 1394: EPC
# 1395: VIR
# 1396: EPAY
# 1397: OI
# 1398: WWE
# 1399: PRAA
# 1400: UI
# 1401: ALLO
# 1402: MAXR
# 1403: PD
# 1404: BEAT
# 1405: PDCE
# 1406: RCII
# 1407: SMPL
# 1408: PRGS
# 1409: OTTR
# 1410: CTRE
# 1411: PGRE
# 1412: ELY
# 1413: EGHT
# 1414: CSWI
# 1415: LPRO
# 1416: DY
# 1417: CPK
# 1418: CADE
# 1419: SANM
# 1420: IRWD
# 1421: FIX
# 1422: MD
# 1423: BECN
# 1424: GHC
# 1425: SASR
# 1426: HTH
# 1427: FRME
# 1428: FBC
# 1429: IBOC
# 1430: SJW
# 1431: MLI
# 1432: CXP
# 1433: AX
# 1434: RMBS
# 1435: JELD
# 1436: CNK
# 1437: WSBC
# 1438: NMIH
# 1439: AVYA
# 1440: NSA
# 1441: MGRC
# 1442: ITCI
# 1443: LZB
# 1444: QURE
# 1445: TSE
# 1446: DRH
# 1447: LILAK
# 1448: TRN
# 1449: FCPT
# 1450: MNR
# 1451: ESRT
# 1452: NNI
# 1453: BDC
# 1454: HCSG
# 1455: KRTX
# 1456: MRSN
# 1457: CUB
# 1458: HRI
# 1459: MUR
# 1460: AVAV
# 1461: CSGS
# 1462: TUP
# 1463: ATSG
# 1464: ATI
# 1465: TRMK
# 1466: CMPR
# 1467: CCS
# 1468: HNI
# 1469: THRM
# 1470: TWO
# 1471: RNST
# 1472: EDIT
# 1473: SFBS
# 1474: LOB
# 1475: NTCT
# 1476: CWK
# 1477: PRFT
# 1478: MTSI
# 1479: CAKE
# 1480: SRNE
# 1481: MNRO
# 1482: SKY
# 1483: ROIC
# 1484: SIG
# 1485: BGS
# 1486: CVCO
# 1487: CENTA
# 1488: PATK
# 1489: SPWR
# 1490: PIPR
# 1491: WRE
# 1492: CAR
# 1493: TBK
# 1494: NWN
# 1495: PLMR
# 1496: CALM
# 1497: ATGE
# 1498: AMWD
# 1499: SBH
# retrying on failed symbols
# 77: XTSLA
# failure occured
# 562: MSFUT
# failure occured

# %%
import pandas as pd
import os

def combine_data(datadir='data', output_file='all_symbols.parquet'):
    files = os.listdir(datadir)
    dfs = []
    cols = ['adj_close', 'adj_open', 'adj_low', 'adj_high', 'Close', 'symbol', 'sector', 'Date', 'Volume']
    for f in files:
        dfs.append(pd.read_parquet('%s/%s' % (datadir, f)).reset_index()[cols])
    ttl_df = pd.concat(dfs, axis=0, ignore_index=True)
    ttl_df.to_parquet(output_file)

# %%
combine_data()

# %%
df = get_symbol_data('SPY', history_length, apikey)
df.reset_index().to_parquet('market_index.parquet')

# %%
import pandas as pd
all_df = pd.read_parquet('all_symbols.parquet')
sector_indices = all_df.groupby(['sector', 'Date']).agg({'adj_close': 'sum'}).reset_index()

# %%
sector_indices.to_parquet('sector_index.parquet')
